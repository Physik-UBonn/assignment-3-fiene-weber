# %% [markdown]
# # H.3 Adiabatic Search of the Ground State

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from functools import reduce
from scipy.sparse import identity, kron, csr_matrix
from scipy.linalg import expm, eigh

# %% [markdown]
# c) Compute the energy gap using exact diagonalisation for different transverse field strengths

# %%
# Create Hamiltonian as matrix as done in last sheet:

# Create csr Pauli matrices
id = identity(2, format='csr')
sigma_x = csr_matrix([[0, 1], [1, 0]], dtype=np.float64)
sigma_z = csr_matrix([[1, 0], [0, -1]], dtype=np.float64)

def kronecker(operators):
    # reduce calls the function (first arg) recursively on the list (second arg)
    return reduce(kron, operators)

def build_operator(operator, ind, L):
    # list of L identity operators
    operators = [id] * L

    # replace the ind-th operator with the given operator
    operators[ind] = operator

    # return the kronecker product of all identity matrices and the operator on site ind
    return csr_matrix(kronecker(operators))

def all_operators(operator, L):
    # a list of L operators, each one acting on a different site, otherwise identity
    return [build_operator(operator, j, L) for j in range(L)]

def Hamiltonian(h=1, J=1, L=4):
    # initialize matrices
    H = csr_matrix((2**L, 2**L), dtype=np.complex128)
    sz_list = all_operators(sigma_z, L)
    sx_list = all_operators(sigma_x, L)

    for i in range(L-1):
        H += -J*(sz_list[i] @ sz_list[i+1]) - h*(sx_list[i])
    return H

# %%
def energy_gap(L, h_max, steps):
    delta_Es = []

    for h in np.linspace(0, h_max, steps):
        H = Hamiltonian(h=h, J=1, L=L)#.todense()

        # diagonalize the Hamiltonian
        e, v = eigh(H.toarray())
        
        delta_Es.append(e[1] - e[0])  # due to symmetry, this works (degenerate ground state)
    return delta_Es

# %%
nsteps, h_max = 1000, 2

delta_Es_L4 = energy_gap(L=4, h_max=h_max, steps=nsteps)
delta_Es_L6 = energy_gap(L=6, h_max=h_max, steps=nsteps)

fig, ax = plt.subplots()

ax.plot(np.linspace(0, h_max, nsteps), delta_Es_L4, label='L=4')
ax.plot(np.linspace(0, h_max, nsteps), delta_Es_L6, label='L=6')

ax.set_xlabel('h')
ax.set_ylabel('Energy gap')

ax.legend()

plt.tight_layout()

# %% [markdown]
# d) Compute the ground state of the TFIM from the ground state without an external field

# %%
def wrap_hamiltonian(h, J, L):   # create wrappers to make function suitable for any integration function
    def wrapper(s):
        return Hamiltonian(h=h, J=J, L=L)
    return wrapper

# %%
def dpsi_dt(s, psi, H, L):
    if np.linalg.norm(psi.view(dtype=np.complex256)) > 0:
        psi = psi.view(dtype=np.complex256) / np.linalg.norm(psi.view(dtype=np.complex256))   # periodical normalization to suppress accumulation of numerical errors resulting from matrix multiplication
    else:
        psi = psi.view(dtype=np.complex256)
    return (-1j * H @ psi).view(dtype=np.float128)

def dpsidt_wrapper(h, J, L):
    H_int = Hamiltonian(h, J, L)
    H0 = Hamiltonian(0, J, L)

    def wrapper(s, psi):
        H = (1 - s) * H0 + s * H_int
        return dpsi_dt(s, psi, H=H, L=L)
    
    return wrapper

# %%
h, J, L = 2, 1, 4

# %%
# find ground state of H0 numerically
H0 = Hamiltonian(0, J, L)
e, v = eigh(H0.toarray())

# ground state is the first eigenvector
ground_state_psi = (v[:, 0] + v[:, 1]) / np.sqrt(2)  # superposition of two degenerate ground states
psi0 = ground_state_psi.view(dtype=np.float128) + 1j*np.zeros((16), dtype=np.float128)  # to create large memory space for high precisions
print(psi0)
# Out:
# [1.67844826e-4932+0.j 0.00000000e+0000+0.j 0.00000000e+0000+0.j
#  0.00000000e+0000+0.j 0.00000000e+0000+0.j 0.00000000e+0000+0.j
#  0.00000000e+0000+0.j 0.00000000e+0000+0.j 0.00000000e+0000+0.j
#  0.00000000e+0000+0.j 0.00000000e+0000+0.j 0.00000000e+0000+0.j
#  0.00000000e+0000+0.j 0.00000000e+0000+0.j 0.00000000e+0000+0.j
#  1.67844826e-4932+0.j]

# %% [markdown]
# If the precision is not set to more than 17 digits, eigh() calculates degenerate groundstates.

# %%
# integration
dpsidt = dpsidt_wrapper(h, J, L)
Nsteps = 1000

print(np.shape((-1j * Hamiltonian(0,J,L) @ psi0).view(dtype=np.float128)))    
print(np.shape(psi0.view(dtype=np.float128)))

sol = solve_ivp(dpsidt, t_span = (0, 1), y0 = psi0.view(dtype=np.float128), t_eval=np.linspace(0, 1, Nsteps))
psi_tau_list = sol.y.T.copy().view(dtype=np.complex256)
psi_tau_list_norm = psi_tau_list / np.linalg.norm(psi_tau_list) # same reason for normalization as before
adiabatic_groundstate = psi_tau_list[-1]
# Out:
# (32,)
# (32,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 8
#       5 print(np.shape((-1j * Hamiltonian(0,J,L) @ psi0).view(dtype=np.float128)))
#       6 print(np.shape(psi0.view(dtype=np.float128)))
# ----> 8 sol = solve_ivp(dpsidt, t_span = (0, 1), y0 = psi0.view(dtype=np.float128), t_eval=np.linspace(0, 1, Nsteps))
#       9 psi_tau_list = sol.y.T.copy().view(dtype=np.complex256)
#      10 psi_tau_list_norm = psi_tau_list / np.linalg.norm(psi_tau_list) # same reason for normalization as before
#
# File /usr/lib/python3/dist-packages/scipy/integrate/_ivp/ivp.py:568, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     565 if method in METHODS:
#     566     method = METHODS[method]
# --> 568 solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     570 if t_eval is None:
#     571     ts = [t0]
#
# File /usr/lib/python3/dist-packages/scipy/integrate/_ivp/rk.py:94, in RungeKutta.__init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, vectorized, first_step, **extraneous)
#      92 self.max_step = validate_max_step(max_step)
#      93 self.rtol, self.atol = validate_tol(rtol, atol, self.n)
# ---> 94 self.f = self.fun(self.t, self.y)
#      95 if first_step is None:
#      96     self.h_abs = select_initial_step(
#      97         self.fun, self.t, self.y, self.f, self.direction,
#      98         self.error_estimator_order, self.rtol, self.atol)
#
# File /usr/lib/python3/dist-packages/scipy/integrate/_ivp/base.py:154, in OdeSolver.__init__.<locals>.fun(t, y)
#     152 def fun(t, y):
#     153     self.nfev += 1
# --> 154     return self.fun_single(t, y)
#
# File /usr/lib/python3/dist-packages/scipy/integrate/_ivp/base.py:23, in check_arguments.<locals>.fun_wrapped(t, y)
#      22 def fun_wrapped(t, y):
# ---> 23     return np.asarray(fun(t, y), dtype=dtype)
#
# Cell In[71], line 14, in dpsidt_wrapper.<locals>.wrapper(s, psi)
#      12 def wrapper(s, psi):
#      13     H = (1 - s) * H0 + s * H_int
# ---> 14     return dpsi_dt(s, psi, H=H, L=L)
#
# Cell In[71], line 6, in dpsi_dt(s, psi, H, L)
#       4 else:
#       5     psi = psi.view(dtype=np.complex256)
# ----> 6 return (-1j * H @ psi).view(dtype=np.float128)
#
# File /usr/lib/python3/dist-packages/scipy/sparse/_base.py:624, in _spbase.__matmul__(self, other)
#     621 if isscalarlike(other):
#     622     raise ValueError("Scalar operands are not allowed, "
#     623                      "use '*' instead")
# --> 624 return self._mul_dispatch(other)
#
# File /usr/lib/python3/dist-packages/scipy/sparse/_base.py:553, in _spbase._mul_dispatch(self, other)
#     550 if other.ndim == 1 or other.ndim == 2 and other.shape[1] == 1:
#     551     # dense row or column vector
#     552     if other.shape != (N,) and other.shape != (N, 1):
# --> 553         raise ValueError('dimension mismatch')
#     555     result = self._mul_vector(np.ravel(other))
#     557     if isinstance(other, np.matrix):
#
# ValueError: dimension mismatch

# %% [markdown]
# e) Comparison of ground state energies found with the adiabatic search and with exact diagonalization over time

# %%
exact_E0 = np.zeros(Nsteps)
adiabatic_E0 = np.zeros(Nsteps)
overlap = np.zeros(Nsteps)
overlap_subspace = np.zeros(Nsteps, dtype=object)
projected_psi = np.zeros((Nsteps, 2**L), dtype=np.complex256)

H0 = Hamiltonian(0, J, L)
H_h = Hamiltonian(h, J, L)

for i, s in enumerate(np.linspace(0, 1, Nsteps)):
    # Get the Hamiltonian at time s
    H = (1 - s) * H0 + s * H_h
    
    # exact ground state energy at time s
    e, v = eigh(H.toarray())

    exact_E0[i] = e[0]

    # adiabatic ground state energy at time s
    adiabatic_E0[i] = np.real(psi_tau_list[i] @ H @ psi_tau_list[i].conjugate())

    # overlap between evolving psi and exact ground state -> compare found ground state wit both degenerate states
    # define projection operator
    #P1 = np.outer(v[:, 0], np.conj(v[:, 0]))
    #P2 = np.outer(v[:, 1], np.conj(v[:, 1]))
    #P = P1 + P2
    
    #projected_psi[i] = P @ psi_tau_list[i]
    #overlap_subspace[i] = [np.vdot(psi_tau_list[i], P1 @ psi_tau_list[i]).real, np.vdot(psi_tau_list[i], P2 @ psi_tau_list[i]).real]
    #overlap[i] = np.max([np.abs(psi_tau_list[i] @ v[:, 0].conjugate()), np.abs(psi_tau_list[i] @ v[:, 1].conjugate())])
    
    # no degeneracy:
    overlap[i] = np.abs(psi_tau_list[i] @ v[:, 0].conjugate())

# %%
plt.plot(sol.t, exact_E0, label='Exact Diagonalization')
plt.plot(sol.t, adiabatic_E0, label='Adiabatic Search')
plt.legend()
plt.xlabel(r'Field strength $\frac{th}{Th_f}$')
plt.ylabel(r'Groundstate Energy $E_0$')
# Out:
# Text(0, 0.5, 'Groundstate Energy $E_0$')

# %% [markdown]
# f) Comparison of the ground states found with the adiabatic search and with exact diagonalization over time

# %%
plt.plot(sol.t, overlap) #already calculated in time loop in e)
plt.xlabel(r'Field strength $\frac{th}{Th_f}$')
plt.xlim(0,1)
plt.ylim(0.4,1)
plt.vlines(0.5,0,1,color="red",label=r'$h=h_c$')
plt.legend()
plt.title(r'Overlap of adiabatically found and degenerate exact groundstates')
plt.ylabel(r'$<\psi_{0}^{ad}|\psi_{0}^{ED}>$');

# %%
# overlap of adiabatically found and subspace spanned by degenerate exact groundstates
error = np.zeros(Nsteps)
check_subspace = np.zeros(Nsteps)

for i in range(Nsteps):
    error[i] = np.linalg.norm(psi_tau_list[i] - projected_psi[i]) 
    check_subspace[i] = np.sum(overlap_subspace[i])  # check if overlap is conserved

# %%
plt.scatter(sol.t, check_subspace, marker='.', s=10, label='Overlap with subspace', zorder=2)
plt.scatter(sol.t, error, marker='.', s=10, label='Error', zorder=1)
plt.hlines(0.5, 0, 1, color="gray", linestyles='--', zorder=0)

plt.xlabel(r'Field strength $\frac{th}{Th_f}$')
plt.ylabel(r'$<\psi_{0}^{ad}|P_{ED}|\psi_{0}^{ad}>$')
plt.title(r'Overlap with subspace of degenerate ED groundstates')

plt.xlim(0, 1)
plt.ylim(0, 1.1)

plt.legend()
plt.tight_layout();

# %% [markdown]
# g) At the quantum phase transition the adiabatic search stops evolving away from the true groundstate and starts converging towards it.
# The found ground state as well as its energy should match the results obtained with exact diagonalization for the final field strength $h_f$. The spikes visible for high magnetic field strengths could indicate that the calculated state left the ground state of the system, which could be due to a too fast evolution, however they don't disappear for higher numbers of timesteps.
